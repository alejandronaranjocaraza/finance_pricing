# %%
import sys
sys.path.append('../build')
import pricer

# %%
vanillaOption = pricer.makeVanillaOption(2,3)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 vanillaOption.canExercise()
#
# TypeError: canExercise(): incompatible function arguments. The following argument types are supported:
#     1. (self: pricer.VanillaOption, t: typing.SupportsFloat) -> bool
#
# Invoked with: <pricer.VanillaOption object at 0x7f77a41ef9b0>

# %%
vanillaOption.payof
# Out:
# 0.5
