# %%
import math
import sys
sys.path.append('../build')
import pricer
import matplotlib.pyplot as plt

# %% [markdown]
# #### Example 1: Baseline

# %%
T = 1
K = 100
optType = 'c'
exeType = 'e'

S0 = 100
r = 0.05
q = 0

sigma = 0.2
n = 100

# %%
# Build option

vanillaOption = pricer.makeVanillaOption(K,T,exeType,optType)

# Bulild stock

stock = pricer.makeStock(S0,q)

# Build binomial model

binomial = pricer.makeBinomial(vanillaOption,stock,r,sigma,n)

# Build Black-Scholes-Metron model

bsm = pricer.makeBSM(vanillaOption,stock,r,sigma)

# %%
# Get vanilla option price through binomial tree (backwards induction)

print(binomial.getPrice())

# Get vanilla option price from Black-Scholes-Merton formula

print(bsm.getPrice())
# Out:
# 10.430611662249142
# 10.450583572185565

# %%
# Run binomial pricer with different number of iterations / time steps

numIters = []
prices = []

for n in range (1,26):
    numIters.append(n*20)
    binomial = pricer.makeBinomial(vanillaOption,stock,r,sigma,n*20)
    prices.append(binomial.getPrice())

plt.plot(numIters,prices)
plt.xlabel("Iterations / Time steps")
plt.ylabel("Price")
plt.title("Binomial Tree Convergence to BSM Price with Increasing Iterations")
plt.show()

# %%
optType = 'p'

# %%
# Build option

vanillaOption = pricer.makeVanillaOption(K,T,exeType,optType)

# Bulild stock

stock = pricer.makeStock(S0,q)

# Build binomial model

binomial = pricer.makeBinomial(vanillaOption,stock,r,sigma,n)

# Build Black-Scholes-Metron model

bsm = pricer.makeBSM(vanillaOption,stock,r,sigma)

# %%
# Get vanilla option price through binomial tree (backwards induction)

print(binomial.getPrice())

# Get vanilla option price from Black-Scholes-Merton formula

print(bsm.getPrice())
# Out:
# 5.643908074055252
# 5.573526022256971

# %%
# Run binomial pricer with different number of iterations / time steps

numIters = []
prices = []

for n in range (1,26):
    numIters.append(n*20)
    binomial = pricer.makeBinomial(vanillaOption,stock,r,sigma,n*20)
    prices.append(binomial.getPrice())

plt.plot(numIters,prices)
plt.xlabel("Iterations / Time steps")
plt.ylabel("Price")
plt.title("Binomial Tree Convergence to BSM Price with Increasing Iterations")
plt.show()

# %% [markdown]
# #### Example 2: Put Call Parity

# %%
T = 2
K = 100
optType = 'c'
exeType = 'e'

S0 = 120
r = 0.03
q = 0

sigma = 0.25
n = 1000

# %%
# Build option

vanillaOption = pricer.makeVanillaOption(K,T,exeType,optType)

# Bulild stock

stock = pricer.makeStock(S0,q)

# Build binomial model

binomial = pricer.makeBinomial(vanillaOption,stock,r,sigma,n)

# Build Black-Scholes-Metron model

bsm = pricer.makeBSM(vanillaOption,stock,r,sigma)

# %%
# Get vanilla option price through binomial tree (backwards induction)

binomialCall = binomial.getPrice()
print(binomialCall)

# Get vanilla option price from Black-Scholes-Merton formula

print(bsm.getPrice())
# Out:
# 31.279687624099125
# 31.279802719901866

# %%
# Run binomial pricer with different number of iterations / time steps

numIters = []
prices = []

for n in range (1,26):
    numIters.append(n*20)
    binomial = pricer.makeBinomial(vanillaOption,stock,r,sigma,n*20)
    prices.append(binomial.getPrice())

plt.plot(numIters,prices)
plt.xlabel("Iterations / Time steps")
plt.ylabel("Price")
plt.title("Binomial Tree Convergence to BSM Price with Increasing Iterations")
plt.show()

# %%
optType = 'p'

# %%
# Build option

vanillaOption = pricer.makeVanillaOption(K,T,exeType,optType)

# Bulild stock

stock = pricer.makeStock(S0,q)

# Build binomial model

binomial = pricer.makeBinomial(vanillaOption,stock,r,sigma,n)

# Build Black-Scholes-Metron model

bsm = pricer.makeBSM(vanillaOption,stock,r,sigma)

# %%
# Get vanilla option price through binomial tree (backwards induction)

binomialPut = binomial.getPrice()
print(binomialPut)

# Get vanilla option price from Black-Scholes-Merton formula

print(bsm.getPrice())
# Out:
# 5.495139701943137
# 5.456256078326742

# %%
# Run binomial pricer with different number of iterations / time steps

numIters = []
prices = []

for n in range (1,26):
    numIters.append(n*20)
    binomial = pricer.makeBinomial(vanillaOption,stock,r,sigma,n*20)
    prices.append(binomial.getPrice())

plt.plot(numIters,prices)
plt.xlabel("Iterations / Time steps")
plt.ylabel("Price")
plt.title("Binomial Tree Convergence to BSM Price with Increasing Iterations")
plt.show()

# %%
print(S0 - K * math.exp(-r*T))
print(binomialCall - binomialPut)
# Out:
# 25.823546641575135
# 25.784547922155987

# %% [markdown]
# #### Example 3: Deep ITM Option

# %%
T = 1
K = 100
optType = 'c'
exeType = 'e'

S0 = 200
r = 0.05
q = 0

sigma = 0.2
n = 1000

# %%
# Build option

vanillaOption = pricer.makeVanillaOption(K,T,exeType,optType)

# Bulild stock

stock = pricer.makeStock(S0,q)

# Build binomial model

binomial = pricer.makeBinomial(vanillaOption,stock,r,sigma,n)

# Build Black-Scholes-Metron model

bsm = pricer.makeBSM(vanillaOption,stock,r,sigma)

# %%
# Get vanilla option price through binomial tree (backwards induction)

binomialCall = binomial.getPrice()
print(binomialCall)

# Get vanilla option price from Black-Scholes-Merton formula

print(bsm.getPrice())
# Out:
# 104.8777156117045
# 104.87772423432371

# %%
# Run binomial pricer with different number of iterations / time steps

numIters = []
prices = []

for n in range (1,26):
    numIters.append(n*20)
    binomial = pricer.makeBinomial(vanillaOption,stock,r,sigma,n*20)
    prices.append(binomial.getPrice())

plt.plot(numIters,prices)
plt.xlabel("Iterations / Time steps")
plt.ylabel("Price")
plt.title("Binomial Tree Convergence to BSM Price with Increasing Iterations")
plt.show()

# %%
optType = 'p'

# %%
# Build option

vanillaOption = pricer.makeVanillaOption(K,T,exeType,optType)

# Bulild stock

stock = pricer.makeStock(S0,q)

# Build binomial model

binomial = pricer.makeBinomial(vanillaOption,stock,r,sigma,n)

# Build Black-Scholes-Metron model

bsm = pricer.makeBSM(vanillaOption,stock,r,sigma)

# %%
# Get vanilla option price through binomial tree (backwards induction)

binomialPut = binomial.getPrice()
print(binomialPut)

# Get vanilla option price from Black-Scholes-Merton formula

print(bsm.getPrice())
# Out:
# 0.00030414118430084993
# 0.0006666843951132258

# %%
# Run binomial pricer with different number of iterations / time steps

numIters = []
prices = []

for n in range (1,26):
    numIters.append(n*20)
    binomial = pricer.makeBinomial(vanillaOption,stock,r,sigma,n*20)
    prices.append(binomial.getPrice())

plt.plot(numIters,prices)
plt.xlabel("Iterations / Time steps")
plt.ylabel("Price")
plt.title("Binomial Tree Convergence to BSM Price with Increasing Iterations")
plt.show()

# %%
print(S0 - K * math.exp(-r * T))
print(binomialCall)
# Out:
# 104.8770575499286
# 104.8777156117045

# %% [markdown]
# #### Example 4. Deep OTM Option

# %%
T = 1
K = 100
optType = 'c'
exeType = 'e'

S0 = 50
r = 0.05
q = 0

sigma = 0.2
n = 1000

# %%
# Build option

vanillaOption = pricer.makeVanillaOption(K,T,exeType,optType)

# Bulild stock

stock = pricer.makeStock(S0,q)

# Build binomial model

binomial = pricer.makeBinomial(vanillaOption,stock,r,sigma,n)

# Build Black-Scholes-Metron model

bsm = pricer.makeBSM(vanillaOption,stock,r,sigma)

# %%
# Get vanilla option price through binomial tree (backwards induction)

binomialCall = binomial.getPrice()
print(binomialCall)

# Get vanilla option price from Black-Scholes-Merton formula

print(bsm.getPrice())
# Out:
# 0.002366016380139772
# 0.002399417553309663

# %%
# Run binomial pricer with different number of iterations / time steps

numIters = []
prices = []

for n in range (1,26):
    numIters.append(n*20)
    binomial = pricer.makeBinomial(vanillaOption,stock,r,sigma,n*20)
    prices.append(binomial.getPrice())

plt.plot(numIters,prices)
plt.xlabel("Iterations / Time steps")
plt.ylabel("Price")
plt.title("Binomial Tree Convergence to BSM Price with Increasing Iterations")
plt.show()

# %%
optType = 'p'

# %%
# Build option

vanillaOption = pricer.makeVanillaOption(K,T,exeType,optType)

# Bulild stock

stock = pricer.makeStock(S0,q)

# Build binomial model

binomial = pricer.makeBinomial(vanillaOption,stock,r,sigma,n)

# Build Black-Scholes-Metron model

bsm = pricer.makeBSM(vanillaOption,stock,r,sigma)

# %%
# Get vanilla option price through binomial tree (backwards induction)

binomialPut = binomial.getPrice()
print(binomialPut)

# Get vanilla option price from Black-Scholes-Merton formula

print(bsm.getPrice())
# Out:
# 45.12401912378238
# 45.12534186762472

# %%
# Run binomial pricer with different number of iterations / time steps

numIters = []
prices = []

for n in range (1,26):
    numIters.append(n*20)
    binomial = pricer.makeBinomial(vanillaOption,stock,r,sigma,n*20)
    prices.append(binomial.getPrice())

plt.plot(numIters,prices)
plt.xlabel("Iterations / Time steps")
plt.ylabel("Price")
plt.title("Binomial Tree Convergence to BSM Price with Increasing Iterations")
plt.show()

# %%
print(binomialPut)
print(K * math.exp(-r*T) - S0)
# Out:
# 45.12401912378238
# 45.122942450071406

# %% [markdown]
# #### 5. Example: Zero Volatility

# %%
T = 1
K = 100
optType = 'c'
exeType = 'e'

S0 = 100
r = 0.05
q = 0

sigma = 0.0
n = 1000

# %%
# Build option

vanillaOption = pricer.makeVanillaOption(K,T,exeType,optType)

# Bulild stock

stock = pricer.makeStock(S0,q)

# Build binomial model

binomial = pricer.makeBinomial(vanillaOption,stock,r,sigma,n)

# Build Black-Scholes-Metron model

bsm = pricer.makeBSM(vanillaOption,stock,r,sigma)

# %%
# Get vanilla option price through binomial tree (backwards induction)

binomialCall = binomial.getPrice()
print(binomialCall)

# Get vanilla option price from Black-Scholes-Merton formula

print(bsm.getPrice())
# Out:
# 4.877057549928611
# 4.877057549928594

# %%
# Run binomial pricer with different number of iterations / time steps

numIters = []
prices = []

for n in range (1,26):
    numIters.append(n*20)
    binomial = pricer.makeBinomial(vanillaOption,stock,r,sigma,n*20)
    prices.append(binomial.getPrice())

plt.plot(numIters,prices)
plt.xlabel("Iterations / Time steps")
plt.ylabel("Price")
plt.title("Binomial Tree Convergence to BSM Price with Increasing Iterations")
plt.show()

# %%
optType = 'p'

# %%
# Build option

vanillaOption = pricer.makeVanillaOption(K,T,exeType,optType)

# Bulild stock

stock = pricer.makeStock(S0,q)

# Build binomial model

binomial = pricer.makeBinomial(vanillaOption,stock,r,sigma,n)

# Build Black-Scholes-Metron model

bsm = pricer.makeBSM(vanillaOption,stock,r,sigma)

# %%
# Get vanilla option price through binomial tree (backwards induction)

binomialPut = binomial.getPrice()
print(binomialPut)

# Get vanilla option price from Black-Scholes-Merton formula

print(bsm.getPrice())
# Out:
# 0.0
# 0.0

# %%
# Run binomial pricer with different number of iterations / time steps

numIters = []
prices = []

for n in range (1,26):
    numIters.append(n*20)
    binomial = pricer.makeBinomial(vanillaOption,stock,r,sigma,n*20)
    prices.append(binomial.getPrice())

plt.plot(numIters,prices)
plt.xlabel("Iterations / Time steps")
plt.ylabel("Price")
plt.title("Binomial Tree Convergence to BSM Price with Increasing Iterations")
plt.show()
