// %% [markdown]
// We use xeus-cling to complile c++ code in Jupyter Notebook: https://github.com/jupyter-xeus/xeus-cling <br>
// We also use quarto to render the current Notebook: https://quarto.org/

// %%
#include <iostream>
#include <vector>

#define LOG(x) std::cout << x << std::endl;

// %%
int main() {
  std::vector<double> vec(10);
  LOG(vec[0]);
  // Example implementation of binomial tree (backwards induction) to determine price of european call option

  double T = 3.0; // Maturity
  double K = 28.0; // Strike price

  double S0 = 26.0; // Stock start price
  double r = 0.01; // Risk neutral return

  double u = 1.1; // Return if stock price goes up
  double d = 0.9; // Loss is stock price goes down
  int n = 36; // Time steps

  double dt = T / n; // Time step length
  //double discount = std::exp(-dt * r);
  std::vector<double> nodes(n+1); // Initialize nodes
  std::cout << nodes[0] << std::endl;
}
// Out:
// input_line_84:3:10: error: type 'std::vector<double>' does not provide a subscript operator
//   LOG(vec[0]);
//       ~~~^~
// input_line_47:1:29: note: expanded from macro 'LOG'
// #define LOG(x) std::cout << x << std::endl;
//                             ^
// input_line_84:15:21: error: type 'std::vector<double>' does not provide a subscript operator
//   std::cout << nodes[0] << std::endl;
//                ~~~~~^~
// Interpreter Error:

// %%
// Out:
// input_line_80:5:7: error: no member named 'add' in 'std::vector<double, std::allocator<double> >'
// nodes.add(0)
// ~~~~~ ^
// Interpreter Error:

// %%
std::pow(2,2)
// Out:
// 4.0000000

// %%
for(double z : nodes)
    LOG(z);
// Out:
// input_line_68:2:17: error: use of undeclared identifier 'nodes'
//  for(double z : nodes)
//                 ^
// Interpreter Error:

// %%
nodes[0] = 0;
// Out:
// input_line_74:2:2: error: use of undeclared identifier 'nodes'
//  nodes[0] = 0;
//  ^
// Interpreter Error:
